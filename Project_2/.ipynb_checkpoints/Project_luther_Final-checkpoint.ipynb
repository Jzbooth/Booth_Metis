# %% [markdown]
# # Project Luther
#
# ## Summary:
#
# In this project I have gathered data from the MLB in hopes that I can use a linear regression model to accurately predict the salary of any given player based soley on their stats.

# %%
from __future__ import print_function, division
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import defaultdict
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.cross_validation import KFold
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso
from sklearn import feature_selection as f_select
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import preprocessing
import re
# %matplotlib inline

# %%
def adj_r2_score(model,y,yhat):
        """Adjusted R square — put fitted linear model, y value, estimated y value in order
        
            Example:
            In [142]: metrics.r2_score(diabetes_y_train,yhat)
            Out[142]: 0.51222621477934993
        
            In [144]: adj_r2_score(lm,diabetes_y_train,yhat)
            Out[144]: 0.50035823946984515"""
        from sklearn import metrics
        adj = 1 - float(len(y)-1)/(len(y)-len(model.coef_)-1)*(1 - metrics.r2_score(y,yhat))
        return adj

# %% [markdown]
# ## Gathering the data
#
# In this section I will use the beautiful soup and Selenium packages to scrape my data from the internet.

# %% [markdown]
# ## Beautiful Soup

# %%
url = 'http://www.spotrac.com/mlb/statistics/player/' #webiste containing the data

response = requests.get(url)

# %%
response.status_code

# %%
page = response.text

# %%
soup = BeautifulSoup(page,"lxml")

# %%
#collects data and puts it in something we can work with

tables=soup.find_all("table")
rows=[row for row in tables[0].find_all('tr')]

# Just want to look at 1st 20 rows for now
rows=rows[1:]

batters={}
for row in rows:
    items=row.find_all('td')
    player=items[1].find('a')
    batters[player]=[i.text for i in items]
    

list(batters.items())
len(batters)

# %%
#will change the string of dollars into an integer that we can work with.
def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '').replace(' ','')
    return int(moneystring)

# %%
i = 0
batlist = []
while i < len(batters):
    batlist.append(list(batters.items())[i][1])
    i = i + 1

# %%
#splits the name and position into different elements of the list.
i = 0
while i < len(batlist):
    batlist[i].extend(batlist[i][1].split(' '))
    i = i + 1

# %%
#removes the name string from the front

i = 0
while i < len(batlist):
    batlist[i] = batlist[i][:1]+batlist[i][2:]
    i = i + 1

# %%
#removes the period from the last names

i = 0
while i < len(batlist):
    batlist[i][-2] = batlist[i][-2].replace('.','')
    i = i + 1

# %%
#converts the salary string into an integer
i = 0
while i < len(batlist):
    batlist[i][16] = money_to_int(batlist[i][16])
    i = i + 1

# %%
#sets up the headers and creates a data frame
Headers = ['RANK', 'TEAM', 'GP', 'AB', 'H', 'R', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'SALARY', 'FIRST', 'LAST', 'POSITION']
batdf = pd.DataFrame(batlist)

# %%
batdf.columns = Headers

# %% [markdown]
# ## Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

import os

# %%
chromedriver = "/Users/gilliangoodman/Downloads/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

driver = webdriver.Chrome(chromedriver)
driver.get("http://www.spotrac.com/mlb/statistics/player/")

# %%
soup2 = BeautifulSoup(driver.page_source, 'html.parser')

# %%
#collects the data from the html and puts it in something we can work with

tables=soup2.find_all("table")
rows=[row for row in tables[0].find_all('tr')]


rows=rows[1:]

pitchers={}
for row in rows:
    items=row.find_all('td')
    player=items[1].find('a')
    pitchers[player]=[i.text for i in items]
    

list(pitchers.items())

# %%
#removes the key and makes the rest into a list of lists

i = 0
pitchlist = []
while i < len(pitchers):
    pitchlist.append(list(pitchers.items())[i][1])
    i = i + 1

# %%
#adds the first and last names and posistion to the end of each list

i = 0
while i < len(pitchlist):
    pitchlist[i].extend(pitchlist[i][1].split(' '))
    i = i + 1

# %%
#removes the name string from the begining 

i = 0
while i < len(pitchlist):
    pitchlist[i] = pitchlist[i][:1]+pitchlist[i][2:]
    i = i + 1

# %%
#change the string salary into an integer

i = 0
while i < len(pitchlist):
    pitchlist[i][15] = money_to_int(pitchlist[i][15])
    i = i + 1

# %%
#remove the period from the last name

i = 0
while i < len(pitchlist):
    pitchlist[i][-2] = pitchlist[i][-2].replace('.','')
    i = i + 1

# %%
#lay out headers and create my data frame

Headers2 = ['RANK', 'TEAM', 'GP', 'GS', 'IP', 'H', 'R', 'ER', 'BB', 'SO', 'W', 'L', 'SV', 'ERA', 'WHIP', 'SALARY', 'FIRST', 'LAST', 'POSITION']
pitchdf = pd.DataFrame(pitchlist)

# %%
#needed to drop a player because his name added unnecessary columns.  jorge de la hoya name is in an abnormal 
#structure so it was easier to delete.  this should not affect the data much.

pitchdf.drop(pitchdf.index[145])

# %%
pitchdf = pitchdf.drop([19, 20], 1)

# %%
pitchdf.columns = Headers2

# %%
#Now that we have our data frames we need to convert the number entries into floats 

pitchdf[['GP', 'GS', 'IP', 'H', 'R', 'ER', 'BB', 'SO', 'W', 'L', 'SV', 'ERA', 'WHIP']] = pitchdf[['GP', 'GS', 'IP', 'H', 'R', 'ER', 'BB', 'SO', 'W', 'L', 'SV', 'ERA', 'WHIP']].convert_objects(convert_numeric=True)

# %%
Now lets do the same thing for the batters
batdf[['GP', 'AB', 'H', 'R', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS']] = batdf[['GP', 'AB', 'H', 'R', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS']].convert_objects(convert_numeric=True)

# %%
starters = pitchdf[pitchdf['POSITION'] == 'SP']

# %% [markdown]
# My  exploratory analysis can be found in the file project_luther where I discover that this data set doesn't have all of the information necessary.

# %% [markdown]
# ## Gathering data part two
#
# Unfortunately the data that I scraped did not include a very important statistic, age.  Luckily I found another source that was available to download on a csv file.

# %%
pitching = pd.read_csv('Pitchingdata.csv')
batting = pd.read_csv('battersdata.csv')
salaries = pd.read_csv('salariesdata.csv')

# %%
salaries = salaries.drop(["Pos'n", "MLS"], axis=1)

# %%
salaries['Player']
# Out:
# 0        Kershaw, Clayton
# 1           Greinke, Zack
# 2            Price, David
# 3          Hamilton, Josh
# 4          Heyward, Jason
# 5         Cabrera, Miguel
# 6       Verlander, Justin
# 7        Hernandez, Felix
# 8          Pujols, Albert
# 9            Sabathia, CC
# 10            Lester, Jon
# 11         Cano, Robinson
# 12           Hamels, Cole
# 13          Cueto, Johnny
# 14             Mauer, Joe
# 15        Ramirez, Hanley
# 16       Cespedes, Yoenis
# 17       Gonzalez, Adrian
# 18          Posey, Buster
# 19          Scherzer, Max
# 20          Upton, Justin
# 21            Reyes, Jose
# 22            Votto, Joey
# 23       Tanaka, Masahiro
# 24         Crawford, Carl
# 25             Kemp, Matt
# 26          Werth, Jayson
# 27            Reyes, Jose
# 28       Ellsbury, Jacoby
# 29           Davis, Chris
#               ...
# 860      Rodriguez, Joely
# 861     Kivlehan, Patrick
# 862       Campos, Vicente
# 863      Mejia, Adalberto
# 864       Rivero, Armando
# 865    Santander, Anthony
# 866           Taylor, Ben
# 867          Covey, Dylan
# 868            May, Jacob
# 869        Astin, Barrett
# 870         Davis, Rookie
# 871         Garrett, Amir
# 872        Travieso, Nick
# 873        Turner, Stuart
# 874           Diaz, Yandy
# 875        Freeland, Kyle
# 876    Senzatela, Antonio
# 877         Haley, Justin
# 878         Knapp, Andrew
# 879         Stassi, Brock
# 880        Cordoba, Allen
# 881          Diaz, Miguel
# 882         Torrens, Luis
# 883          Gadea, Kevin
# 884        Pruitt, Austin
# 885     Robertson, Daniel
# 886       Hauschild, Mike
# 887        Robinson, Drew
# 888       Sparkman, Glenn
# 889      Marmolejos, Jose
# Name: Player, Length: 890, dtype: object

# %%
batting['Name']
# Out:
# 0              Fernando Abad*\abadfe01
# 1                 Jose Abreu\abreujo02
# 2          Cristhian Adames#\adamecr01
# 3               Austin Adams\adamsau02
# 4                 Lane Adams\adamsla01
# 5                Matt Adams*\adamsma01
# 6                Matt Adams*\adamsma01
# 7                Matt Adams*\adamsma01
# 8                Jim Adduci*\adducji02
# 9                Tim Adleman\adlemti01
# 10           Ehire Adrianza#\adriaeh01
# 11             Jesus Aguilar\aguilje01
# 12                Nick Ahmed\ahmedni01
# 13             Andrew Albers\alberan01
# 14              Matt Albers*\alberma01
# 15             Ozzie Albies#\albieoz01
# 16           Al Alburquerque\albural01
# 17           Al Alburquerque\albural01
# 18      Arismendy Alcantara#\alcanar01
# 19           Sandy Alcantara\alcansa01
# 20          Scott Alexander*\alexasc02
# 21              Jorge Alfaro\alfarjo01
# 22            Anthony Alford\alforan01
# 23                Cody Allen\allenco01
# 24               Greg Allen#\allengr01
# 25          Abraham Almonte#\almonab01
# 26             Albert Almora\almoral01
# 27            Yonder Alonso*\alonsyo01
# 28            Yonder Alonso*\alonsyo01
# 29            Yonder Alonso*\alonsyo01
#                      ...
# 1424             Kolten Wong*\wongko01
# 1425                Alex Wood\woodal02
# 1426               Blake Wood\woodbl01
# 1427               Blake Wood\woodbl01
# 1428              Travis Wood\woodtr01
# 1429              Travis Wood\woodtr01
# 1430              Travis Wood\woodtr01
# 1431       Brandon Woodruff*\woodrbr01
# 1432         Brandon Workman\workmbr01
# 1433            Vance Worley\worleva01
# 1434             Mike Wright\wrighmi01
# 1435         Jimmy Yacabonis\yacabji01
# 1436            Kirby Yates*\yateski01
# 1437            Kirby Yates*\yateski01
# 1438       Christian Yelich*\yelicch01
# 1439             Gabriel Ynoa\ynoaga01
# 1440             Michael Ynoa\ynoami01
# 1441             Chris Young\youngch03
# 1442             Chris Young\youngch04
# 1443             Eric Young#\younger03
# 1444            Mark Zagunis\zagunma01
# 1445           Rob Zastryzny\zastrro01
# 1446            Brad Ziegler\zieglbr01
# 1447         Bradley Zimmer*\zimmebr01
# 1448          Ryan Zimmerman\zimmery01
# 1449       Jordan Zimmermann\zimmejo02
# 1450            Ben Zobrist#\zobribe01
# 1451             Mike Zunino\zuninmi01
# 1452                Tony Zych\zychto01
# 1453                  LgAvg per 600 PA
# Name: Name, Length: 1454, dtype: object

# %%
#lets remove all of those nasty characters from our names so we can merge easily
from string import printable

batting['Name'] = batting['Name'].apply(lambda x: x.split('*',1)[0])
batting['Name'] = batting['Name'].apply(lambda x: x.split('#',1)[0])
batting['Name'] = batting['Name'].apply(lambda x: x.split('\\',1)[0])
batting['Name'] = batting['Name'].apply(lambda x: re.sub("[^{}]+".format(printable), " ", x))
batting['Name'] = batting['Name'].apply(lambda x: x.split(' ',1)[-1] + ',' + ' ' + x.split(' ',1)[0])

# %%
batting['Name']
# Out:
# 0             Abad, Fernando
# 1                Abreu, Jose
# 2          Adames, Cristhian
# 3              Adams, Austin
# 4                Adams, Lane
# 5                Adams, Matt
# 6                Adams, Matt
# 7                Adams, Matt
# 8                Adduci, Jim
# 9               Adleman, Tim
# 10           Adrianza, Ehire
# 11            Aguilar, Jesus
# 12               Ahmed, Nick
# 13            Albers, Andrew
# 14              Albers, Matt
# 15             Albies, Ozzie
# 16          Alburquerque, Al
# 17          Alburquerque, Al
# 18      Alcantara, Arismendy
# 19          Alcantara, Sandy
# 20          Alexander, Scott
# 21             Alfaro, Jorge
# 22           Alford, Anthony
# 23               Allen, Cody
# 24               Allen, Greg
# 25          Almonte, Abraham
# 26            Almora, Albert
# 27            Alonso, Yonder
# 28            Alonso, Yonder
# 29            Alonso, Yonder
#                 ...
# 1424            Wong, Kolten
# 1425              Wood, Alex
# 1426             Wood, Blake
# 1427             Wood, Blake
# 1428            Wood, Travis
# 1429            Wood, Travis
# 1430            Wood, Travis
# 1431       Woodruff, Brandon
# 1432        Workman, Brandon
# 1433           Worley, Vance
# 1434            Wright, Mike
# 1435        Yacabonis, Jimmy
# 1436            Yates, Kirby
# 1437            Yates, Kirby
# 1438       Yelich, Christian
# 1439           Ynoa, Gabriel
# 1440           Ynoa, Michael
# 1441            Young, Chris
# 1442            Young, Chris
# 1443             Young, Eric
# 1444           Zagunis, Mark
# 1445          Zastryzny, Rob
# 1446           Ziegler, Brad
# 1447         Zimmer, Bradley
# 1448         Zimmerman, Ryan
# 1449      Zimmermann, Jordan
# 1450            Zobrist, Ben
# 1451            Zunino, Mike
# 1452              Zych, Tony
# 1453       per 600 PA, LgAvg
# Name: Name, Length: 1454, dtype: object

# %%
#Lets do the same thing with the pitching data
pitching['Name'] = pitching['Name'].apply(lambda x: x.split('*',1)[0])
pitching['Name'] = pitching['Name'].apply(lambda x: x.split('#',1)[0])
pitching['Name'] = pitching['Name'].apply(lambda x: x.split('\\',1)[0])
pitching['Name'] = pitching['Name'].apply(lambda x: re.sub("[^{}]+".format(printable), " ", x))
pitching['Name'] = pitching['Name'].apply(lambda x: x.split(' ',1)[-1] + ',' + ' ' + x.split(' ',1)[0])

# %%
pitching['Name']
# Out:
# 0            Abad, Fernando
# 1             Adams, Austin
# 2              Adleman, Tim
# 3            Albers, Andrew
# 4              Albers, Matt
# 5          Alburquerque, Al
# 6          Alburquerque, Al
# 7          Alburquerque, Al
# 8           Alcantara, Raul
# 9          Alcantara, Sandy
# 10        Alcantara, Victor
# 11         Alexander, Scott
# 12              Allen, Cody
# 13          Almonte, Miguel
# 14           Altavilla, Dan
# 15           Alvarado, Jose
# 16           Alvarez, Dario
# 17       Alvarez, Henderson
# 18            Alvarez, Jose
# 19          Anderson, Brett
# 20          Anderson, Brett
# 21          Anderson, Brett
# 22          Anderson, Chase
# 23           Anderson, Drew
# 24          Anderson, Tyler
# 25           Andriese, Matt
# 26          Aoki, Norichika
# 27           Aquino, Jayson
# 28            Arano, Victor
# 29            Archer, Chris
#                ...
# 892            Winkler, Dan
# 893            Wisler, Matt
# 894          Wittgren, Nick
# 895    Wojciechowski, Asher
# 896              Wood, Alex
# 897             Wood, Blake
# 898             Wood, Blake
# 899             Wood, Blake
# 900            Wood, Hunter
# 901            Wood, Travis
# 902            Wood, Travis
# 903            Wood, Travis
# 904       Woodruff, Brandon
# 905        Workman, Brandon
# 906           Worley, Vance
# 907          Wright, Daniel
# 908            Wright, Mike
# 909          Wright, Steven
# 910        Yacabonis, Jimmy
# 911            Yates, Kirby
# 912            Yates, Kirby
# 913            Yates, Kirby
# 914           Ynoa, Gabriel
# 915           Ynoa, Michael
# 916            Young, Chris
# 917          Zastryzny, Rob
# 918           Ziegler, Brad
# 919      Zimmermann, Jordan
# 920              Zych, Tony
# 921       per 180 IP, LgAvg
# Name: Name, Length: 922, dtype: object

# %%
#narrow down our sample to only players with more than 200 at bats this year
batting2 = batting[batting['AB'] >= 200]

# %%
#narrow down our sample to only players with more than 30 games played this year
pitching2 = pitching[pitching['G'] >= 30]

# %%
salaries.rename(columns={'Player':'Name', '2017' : 'Salary'},inplace = True)

# %%
def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '').replace(' ','')
    return int(moneystring)

# %%
salaries['Salary'] = salaries['Salary'].apply(lambda x: money_to_int(x))

# %%
#lets merge our salaries dataframe with our pitching dataframe 

pitchdf = pd.merge(salaries, pitching2, on=['Name'])

# %%
batdf = pd.merge(salaries, batting2, on=['Name'])

# %%
batdf.columns[30]
# Out:
# 'Pos\xa0Summary'

# %%
batdf.drop_duplicates('Name', inplace = True)

# %%
batdf = batdf.drop(['Rk', 'Tm', 'Lg', 'Pos\xa0Summary'],1)

# %%
pitchdf.drop_duplicates('Name', inplace = True)

# %%
pitchdf = pitchdf.drop(['Rk', 'Tm', 'Lg'],1)

# %%
batdf['intercept'] = 1
pitchdf['intercept'] = 1

# %%
pitchdf.corr()
# Out:
#              Salary       Age         W         L      W-L%       ERA  \
# Salary     1.000000  0.373189  0.433273  0.389039  0.016402  0.005547
# Age        0.373189  1.000000 -0.068667 -0.008345 -0.059979  0.052522
# W          0.433273 -0.068667  1.000000  0.611439  0.290878 -0.068522
# L          0.389039 -0.008345  0.611439  1.000000 -0.371310  0.276107
# W-L%       0.016402 -0.059979  0.290878 -0.371310  1.000000 -0.308612
# ERA        0.005547  0.052522 -0.068522  0.276107 -0.308612  1.000000
# G         -0.350293  0.068180 -0.554933 -0.557348 -0.011804 -0.414439
# GS         0.473351 -0.027509  0.835978  0.830938 -0.023138  0.186806
# GF        -0.141373 -0.029084 -0.427723 -0.362769 -0.075982 -0.261435
# CG         0.346680  0.051132  0.462779  0.380076  0.033437 -0.014462
# SHO        0.188365  0.031228  0.316539  0.354832 -0.022496  0.034794
# SV         0.006378 -0.027515 -0.208614 -0.160695 -0.041646 -0.291009
# IP         0.466783 -0.035938  0.868537  0.821428 -0.009469  0.061373
# H          0.414705 -0.034327  0.794026  0.868783 -0.096137  0.237368
# R          0.424397 -0.011458  0.724902  0.885764 -0.150741  0.392398
# ER         0.416541 -0.007999  0.719834  0.881478 -0.150458  0.404387
# HR         0.488003  0.033253  0.720612  0.813708 -0.097828  0.316466
# BB         0.314447 -0.066423  0.737247  0.776084 -0.078913  0.184173
# IBB       -0.101528  0.091597  0.063534  0.127544 -0.111028  0.040560
# SO         0.501664 -0.059683  0.838096  0.682356  0.063526 -0.093222
# HBP        0.221340 -0.007396  0.552297  0.501861 -0.004725  0.001829
# BK        -0.074154 -0.097440  0.127567  0.132542  0.023718  0.017898
# WP         0.237389 -0.048968  0.429261  0.404368 -0.007516  0.078326
# BF         0.452400 -0.038581  0.855482  0.842886 -0.035562  0.113151
# ERA+       0.054991 -0.033776  0.005494 -0.292415  0.307650 -0.882946
# FIP       -0.026405  0.075806 -0.003154  0.252901 -0.241642  0.740060
# WHIP      -0.133880 -0.035610 -0.112993  0.202024 -0.318840  0.769089
# H9        -0.016048  0.005421  0.017639  0.311484 -0.308357  0.736778
# HR9        0.118214  0.085880  0.042167  0.219085 -0.158914  0.639614
# BB9       -0.216016 -0.068982 -0.228140 -0.107272 -0.106730  0.271183
# SO9        0.050844 -0.077239 -0.115141 -0.296271  0.179857 -0.393171
# SO/W       0.217138  0.027618  0.063490 -0.119242  0.221614 -0.444568
# intercept       NaN       NaN       NaN       NaN       NaN       NaN
#
#                   G        GS        GF        CG    ...            BF  \
# Salary    -0.350293  0.473351 -0.141373  0.346680    ...      0.452400
# Age        0.068180 -0.027509 -0.029084  0.051132    ...     -0.038581
# W         -0.554933  0.835978 -0.427723  0.462779    ...      0.855482
# L         -0.557348  0.830938 -0.362769  0.380076    ...      0.842886
# W-L%      -0.011804 -0.023138 -0.075982  0.033437    ...     -0.035562
# ERA       -0.414439  0.186806 -0.261435 -0.014462    ...      0.113151
# G          1.000000 -0.753535  0.552777 -0.336870    ...     -0.640132
# GS        -0.753535  1.000000 -0.545358  0.472028    ...      0.976892
# GF         0.552777 -0.545358  1.000000 -0.249362    ...     -0.490541
# CG        -0.336870  0.472028 -0.249362  1.000000    ...      0.494042
# SHO       -0.265923  0.365056 -0.194644  0.805235    ...      0.379387
# SV         0.378220 -0.289979  0.909919 -0.127820    ...     -0.243840
# IP        -0.625445  0.970464 -0.479616  0.509147    ...      0.997105
# H         -0.662953  0.960666 -0.511377  0.471976    ...      0.976624
# R         -0.692168  0.944252 -0.520828  0.428801    ...      0.943235
# ER        -0.695558  0.942536 -0.521569  0.414048    ...      0.939358
# HR        -0.673268  0.910409 -0.497482  0.460387    ...      0.907273
# BB        -0.578443  0.880369 -0.455675  0.342537    ...      0.882366
# IBB        0.086765  0.054088 -0.042987 -0.008836    ...      0.103848
# SO        -0.511899  0.859228 -0.362540  0.470020    ...      0.897147
# HBP       -0.386451  0.599714 -0.299291  0.279536    ...      0.607989
# BK        -0.074309  0.132230 -0.047894  0.052778    ...      0.132769
# WP        -0.273227  0.437742 -0.145493  0.301101    ...      0.462344
# BF        -0.640132  0.976892 -0.490541  0.494042    ...      1.000000
# ERA+       0.391566 -0.219684  0.326459 -0.026454    ...     -0.157812
# FIP       -0.374471  0.212558 -0.303616  0.029145    ...      0.146845
# WHIP      -0.268073  0.097568 -0.229860 -0.064509    ...      0.043263
# H9        -0.360323  0.235137 -0.284794  0.049426    ...      0.200807
# HR9       -0.368468  0.209534 -0.212156  0.078479    ...      0.156908
# BB9        0.061512 -0.178891  0.015802 -0.190725    ...     -0.224561
# SO9        0.283647 -0.279802  0.329671 -0.100535    ...     -0.259496
# SO/W       0.133892 -0.055188  0.215919  0.061236    ...     -0.021818
# intercept       NaN       NaN       NaN       NaN    ...           NaN
#
#                ERA+       FIP      WHIP        H9       HR9       BB9  \
# Salary     0.054991 -0.026405 -0.133880 -0.016048  0.118214 -0.216016
# Age       -0.033776  0.075806 -0.035610  0.005421  0.085880 -0.068982
# W          0.005494 -0.003154 -0.112993  0.017639  0.042167 -0.228140
# L         -0.292415  0.252901  0.202024  0.311484  0.219085 -0.107272
# W-L%       0.307650 -0.241642 -0.318840 -0.308357 -0.158914 -0.106730
# ERA       -0.882946  0.740060  0.769089  0.736778  0.639614  0.271183
# G          0.391566 -0.374471 -0.268073 -0.360323 -0.368468  0.061512
# GS        -0.219684  0.212558  0.097568  0.235137  0.209534 -0.178891
# GF         0.326459 -0.303616 -0.229860 -0.284794 -0.212156  0.015802
# CG        -0.026454  0.029145 -0.064509  0.049426  0.078479 -0.190725
# SHO       -0.072220  0.065852 -0.009863  0.070765  0.067402 -0.124571
# SV         0.353944 -0.366254 -0.301666 -0.301972 -0.231316 -0.085950
# IP        -0.110331  0.102488 -0.021806  0.148192  0.133255 -0.261984
# H         -0.268815  0.221771  0.181444  0.374082  0.207270 -0.237679
# R         -0.397847  0.345146  0.255839  0.401508  0.317385 -0.145279
# ER        -0.405030  0.352248  0.259014  0.401141  0.327860 -0.139010
# HR        -0.324240  0.400927  0.128406  0.282919  0.488313 -0.195148
# BB        -0.224918  0.285405  0.233537  0.150646  0.149582  0.191276
# IBB       -0.125613  0.102908  0.202857  0.184503 -0.128994  0.085278
# SO         0.056049 -0.114546 -0.182652 -0.050776  0.069549 -0.251195
# HBP       -0.041032  0.186390  0.025113  0.020762  0.012535  0.015319
# BK        -0.009057  0.097404  0.065276  0.034624  0.011186  0.065670
# WP        -0.121836  0.048735  0.025763 -0.016165  0.070676  0.067824
# BF        -0.157812  0.146845  0.043263  0.200807  0.156908 -0.224561
# ERA+       1.000000 -0.697406 -0.733184 -0.692328 -0.543952 -0.272991
# FIP       -0.697406  1.000000  0.639819  0.500730  0.792974  0.392626
# WHIP      -0.733184  0.639819  1.000000  0.828711  0.334470  0.544432
# H9        -0.692328  0.500730  0.828711  1.000000  0.362181 -0.017730
# HR9       -0.543952  0.792974  0.334470  0.362181  1.000000  0.055670
# BB9       -0.272991  0.392626  0.544432 -0.017730  0.055670  1.000000
# SO9        0.441379 -0.564067 -0.402014 -0.531009 -0.142423  0.079320
# SO/W       0.558979 -0.623691 -0.642010 -0.319552 -0.171525 -0.667655
# intercept       NaN       NaN       NaN       NaN       NaN       NaN
#
#                 SO9      SO/W  intercept
# Salary     0.050844  0.217138        NaN
# Age       -0.077239  0.027618        NaN
# W         -0.115141  0.063490        NaN
# L         -0.296271 -0.119242        NaN
# W-L%       0.179857  0.221614        NaN
# ERA       -0.393171 -0.444568        NaN
# G          0.283647  0.133892        NaN
# GS        -0.279802 -0.055188        NaN
# GF         0.329671  0.215919        NaN
# CG        -0.100535  0.061236        NaN
# SHO       -0.141835  0.000408        NaN
# SV         0.350055  0.315236        NaN
# IP        -0.233087  0.021210        NaN
# H         -0.355304 -0.066074        NaN
# R         -0.375670 -0.143497        NaN
# ER        -0.370741 -0.144071        NaN
# HR        -0.277177 -0.062522        NaN
# BB        -0.222594 -0.298687        NaN
# IBB       -0.318580 -0.273147        NaN
# SO         0.124603  0.211156        NaN
# HBP       -0.222482 -0.135422        NaN
# BK        -0.112385 -0.096679        NaN
# WP         0.045724 -0.081881        NaN
# BF        -0.259496 -0.021818        NaN
# ERA+       0.441379  0.558979        NaN
# FIP       -0.564067 -0.623691        NaN
# WHIP      -0.402014 -0.642010        NaN
# H9        -0.531009 -0.319552        NaN
# HR9       -0.142423 -0.171525        NaN
# BB9        0.079320 -0.667655        NaN
# SO9        1.000000  0.488706        NaN
# SO/W       0.488706  1.000000        NaN
# intercept       NaN       NaN        NaN
#
# [33 rows x 33 columns]

# %%
batdf.corr()
# Out:
#              Salary       Age         G        PA        AB         R  \
# Salary     1.000000  0.614947  0.084252  0.224861  0.204336  0.197061
# Age        0.614947  1.000000 -0.121059 -0.079795 -0.095957 -0.114183
# G          0.084252 -0.121059  1.000000  0.901057  0.895695  0.773676
# PA         0.224861 -0.079795  0.901057  1.000000  0.990169  0.891514
# AB         0.204336 -0.095957  0.895695  0.990169  1.000000  0.859470
# R          0.197061 -0.114183  0.773676  0.891514  0.859470  1.000000
# H          0.205408 -0.118144  0.815214  0.932882  0.943257  0.877092
# 2B         0.166697 -0.086047  0.687224  0.774386  0.774161  0.732575
# 3B        -0.090181 -0.211711  0.289284  0.315172  0.328446  0.382568
# HR         0.136706 -0.097755  0.561015  0.643876  0.604791  0.708917
# RBI        0.217171 -0.077987  0.696260  0.789660  0.763302  0.772062
# SB        -0.059153 -0.196451  0.214962  0.269267  0.285922  0.361818
# CS        -0.022899 -0.160635  0.232079  0.293084  0.311953  0.345049
# BB         0.257385  0.026068  0.570830  0.659341  0.551742  0.716127
# SO        -0.035016 -0.164790  0.589886  0.599231  0.575498  0.563132
# BA         0.104512 -0.101001  0.222841  0.336510  0.342000  0.463725
# OBP        0.176834 -0.010974  0.240773  0.352175  0.266863  0.546879
# SLG        0.092653 -0.108292  0.299858  0.402451  0.365750  0.594472
# OPS        0.132480 -0.081726  0.305253  0.420311  0.362200  0.630677
# OPS+       0.134215 -0.082453  0.297578  0.420445  0.361389  0.621923
# TB         0.190245 -0.132524  0.805556  0.920145  0.909209  0.917027
# GDP        0.293039  0.083086  0.494092  0.553773  0.569031  0.420172
# HBP        0.012459  0.053219  0.214022  0.252023  0.208646  0.274586
# SH        -0.167252 -0.083489  0.020452 -0.085829 -0.063409 -0.124862
# SF         0.167397  0.027551  0.401680  0.438844  0.425260  0.322862
# IBB        0.205933 -0.091666  0.352083  0.396347  0.342883  0.426373
# intercept       NaN       NaN       NaN       NaN       NaN       NaN
#
#                   H        2B        3B        HR    ...           SLG  \
# Salary     0.205408  0.166697 -0.090181  0.136706    ...      0.092653
# Age       -0.118144 -0.086047 -0.211711 -0.097755    ...     -0.108292
# G          0.815214  0.687224  0.289284  0.561015    ...      0.299858
# PA         0.932882  0.774386  0.315172  0.643876    ...      0.402451
# AB         0.943257  0.774161  0.328446  0.604791    ...      0.365750
# R          0.877092  0.732575  0.382568  0.708917    ...      0.594472
# H          1.000000  0.806804  0.363577  0.568290    ...      0.501145
# 2B         0.806804  1.000000  0.206578  0.481805    ...      0.490815
# 3B         0.363577  0.206578  1.000000  0.006550    ...      0.092161
# HR         0.568290  0.481805  0.006550  1.000000    ...      0.801743
# RBI        0.764990  0.676536  0.070981  0.861361    ...      0.720026
# SB         0.306966  0.156378  0.503054 -0.090528    ...     -0.063353
# CS         0.318649  0.181187  0.479691 -0.072760    ...     -0.087812
# BB         0.510164  0.472047  0.113607  0.618462    ...      0.449225
# SO         0.423509  0.317670  0.099565  0.686910    ...      0.349058
# BA         0.619652  0.466487  0.241258  0.210245    ...      0.604870
# OBP        0.466351  0.387737  0.154499  0.366841    ...      0.644293
# SLG        0.501145  0.490815  0.092161  0.801743    ...      1.000000
# OPS        0.533806  0.497149  0.123884  0.712690    ...      0.958601
# OPS+       0.535250  0.483434  0.103134  0.683121    ...      0.925280
# TB         0.930540  0.801476  0.290091  0.821460    ...      0.702517
# GDP        0.574197  0.459309 -0.081762  0.398849    ...      0.265657
# HBP        0.204043  0.167937  0.087896  0.193034    ...      0.160553
# SH        -0.068112 -0.120831  0.177304 -0.316122    ...     -0.308425
# SF         0.416846  0.399989  0.007000  0.280360    ...      0.214407
# IBB        0.385592  0.366652  0.088781  0.417200    ...      0.401710
# intercept       NaN       NaN       NaN       NaN    ...           NaN
#
#                 OPS      OPS+        TB       GDP       HBP        SH  \
# Salary     0.132480  0.134215  0.190245  0.293039  0.012459 -0.167252
# Age       -0.081726 -0.082453 -0.132524  0.083086  0.053219 -0.083489
# G          0.305253  0.297578  0.805556  0.494092  0.214022  0.020452
# PA         0.420311  0.420445  0.920145  0.553773  0.252023 -0.085829
# AB         0.362200  0.361389  0.909209  0.569031  0.208646 -0.063409
# R          0.630677  0.621923  0.917027  0.420172  0.274586 -0.124862
# H          0.533806  0.535250  0.930540  0.574197  0.204043 -0.068112
# 2B         0.497149  0.483434  0.801476  0.459309  0.167937 -0.120831
# 3B         0.123884  0.103134  0.290091 -0.081762  0.087896  0.177304
# HR         0.712690  0.683121  0.821460  0.398849  0.193034 -0.316122
# RBI        0.682389  0.652860  0.897204  0.563402  0.168900 -0.272437
# SB        -0.016552 -0.005166  0.179237 -0.092633  0.044966  0.273996
# CS        -0.046473 -0.038459  0.195412 -0.050622  0.096189  0.269765
# BB         0.566644  0.568010  0.624664  0.277531  0.219214 -0.237957
# SO         0.276578  0.254767  0.586493  0.232956  0.158199 -0.146873
# BA         0.707262  0.710343  0.509987  0.307674  0.104854 -0.043976
# OBP        0.835364  0.844277  0.479913  0.183565  0.304312 -0.178107
# SLG        0.958601  0.925280  0.702517  0.265657  0.160553 -0.308425
# OPS        1.000000  0.979307  0.683546  0.259383  0.228771 -0.287703
# OPS+       0.979307  1.000000  0.668129  0.261048  0.243598 -0.283258
# TB         0.683546  0.668129  1.000000  0.548631  0.225468 -0.183413
# GDP        0.259383  0.261048  0.548631  1.000000  0.009451 -0.242153
# HBP        0.228771  0.243598  0.225468  0.009451  1.000000 -0.010427
# SH        -0.287703 -0.283258 -0.183413 -0.242153 -0.010427  1.000000
# SF         0.206182  0.208008  0.406869  0.347258  0.098402 -0.103335
# IBB        0.460708  0.440086  0.451210  0.289467  0.148418 -0.134374
# intercept       NaN       NaN       NaN       NaN       NaN       NaN
#
#                  SF       IBB  intercept
# Salary     0.167397  0.205933        NaN
# Age        0.027551 -0.091666        NaN
# G          0.401680  0.352083        NaN
# PA         0.438844  0.396347        NaN
# AB         0.425260  0.342883        NaN
# R          0.322862  0.426373        NaN
# H          0.416846  0.385592        NaN
# 2B         0.399989  0.366652        NaN
# 3B         0.007000  0.088781        NaN
# HR         0.280360  0.417200        NaN
# RBI        0.484239  0.469917        NaN
# SB        -0.014312 -0.030590        NaN
# CS         0.015421 -0.036235        NaN
# BB         0.262190  0.535516        NaN
# SO         0.136491  0.181774        NaN
# BA         0.212451  0.290388        NaN
# OBP        0.139237  0.461713        NaN
# SLG        0.214407  0.401710        NaN
# OPS        0.206182  0.460708        NaN
# OPS+       0.208008  0.440086        NaN
# TB         0.406869  0.451210        NaN
# GDP        0.347258  0.289467        NaN
# HBP        0.098402  0.148418        NaN
# SH        -0.103335 -0.134374        NaN
# SF         1.000000  0.155918        NaN
# IBB        0.155918  1.000000        NaN
# intercept       NaN       NaN        NaN
#
# [27 rows x 27 columns]

# %%
est=LinearRegression()
x = batdf.drop(['Salary','Name'],1)
kf=KFold(n=len(x),n_folds=5,shuffle=True)
y = batdf['Salary']
all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 

# get indices of corresponding train & test
for train,test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.05: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
            
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
print(sig_cols)
print(np.mean(all_scores))
# Out:
# ['Age', 'PA', 'AB', 'R', 'H', '2B', 'RBI', 'BB', 'OBP', 'OPS', 'OPS+', 'TB', 'GDP', 'SF', 'IBB']
# 0.437646805663
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:303: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
x = batdf[sig_cols]
y = batdf['Salary']
lr = LinearRegression()
lr.fit(x,y)

# Fit the model to the full dataset


print('Fit score (R^2) is: %f'%lr.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(lr, y, lr.predict(x)))
print('Fit intercept is: %f'%lr.intercept_)
print('Mean of the target value is: %f'%y.mean())
lr.coef_
# Out:
# Fit score (R^2) is: 0.507747
# Adj R^2 is: 0.480994
# Fit intercept is: -27818290.103726
# Mean of the target value is: 6247631.760274
# array([  1163396.4219153 ,   -158797.28094928,    157894.86934967,
#            46247.9712104 ,     42796.09864708,    -27431.78566414,
#            24717.67926886,    168447.4670842 ,   1308146.01491436,
#        -11896829.15905595,     41322.34757426,    -25031.2212633 ,
#           103451.34750982,    246257.86967965,    340807.44519642])

# %%
x = batdf[sig_cols]
y = batdf['Salary']
lr = LinearRegression()
fit = lr.fit(x,y)
y_predicted = fit.predict(x)
y_predicted

predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('Salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %%
pitchdf.columns[3:]
# Out:
# Index(['W', 'L', 'W-L%', 'ERA', 'G', 'GS', 'GF', 'CG', 'SHO', 'SV', 'IP', 'H',
#        'R', 'ER', 'HR', 'BB', 'IBB', 'SO', 'HBP', 'BK', 'WP', 'BF', 'ERA+',
#        'FIP', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9', 'SO/W', 'intercept'],
#       dtype='object')

# %%
pitchdf = pitchdf.dropna()
est=LinearRegression()
x = pitchdf.drop(['Salary','Name'],1)
kf=KFold(n=len(x),n_folds=5,shuffle=True)
y = pitchdf['Salary']
all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 
# get indices of corresponding train & test
for train,test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.05: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
print(sig_cols)
print(np.mean(all_scores))
# Out:
# ['Age', 'W', 'L', 'G', 'GS', 'CG', 'SHO', 'IP', 'H', 'R', 'ER', 'HR', 'BB', 'SO', 'HBP', 'WP', 'BF', 'BB9', 'SO/W']
# 0.397854695332
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:303: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
x = pitchdf[sig_cols]
y = pitchdf['Salary']
lr = LinearRegression()
lr.fit(x,y)

# Fit the model to the full dataset


print('Fit score (R^2) is: %f'%lr.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(lr, y, lr.predict(x)))
print('Fit intercept is: %f'%lr.intercept_)
print('Mean of the target value is: %f'%y.mean())
lr.coef_
# Out:
# Fit score (R^2) is: 0.534462
# Adj R^2 is: 0.492141
# Fit intercept is: -16873243.618154
# Mean of the target value is: 4196622.720524
# array([  522729.50617981,   163321.14780911,   232117.43801898,
#           21931.54021018,   377947.3474902 ,  1477489.39652927,
#        -2042106.97446668,    82483.17082871,   -70033.23471396,
#          229349.08044076,  -180845.77084832,   130535.21823124,
#         -157360.53376053,    21610.39059955,  -144445.18093346,
#           35181.96868232,   -22134.05569252,  1182621.77670703,
#          540739.0227759 ])

# %%
x = pitchdf[sig_cols]
y = pitchdf['Salary']
lr = LinearRegression()
fit = lr.fit(x,y)
y_predicted = fit.predict(x)
y_predicted

predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('Salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %%
#These are not the best fits so lets try again with logSalary
pitchdf['log_salary'] = np.log(pitchdf.Salary)
batdf['log_salary'] = np.log(batdf.Salary)

# %%
est=LinearRegression()
x = batdf.drop(['Salary','Name', 'log_salary'],1)
kf=KFold(n=len(x),n_folds=5,shuffle=True)
y = batdf['log_salary']
all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 

# get indices of corresponding train & test
for train,test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.05: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
            
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
b1sig_cols = sig_cols
print(b1sig_cols)
print(np.mean(all_scores))
# Out:
# ['Age', 'PA', 'AB', 'R', 'H', '2B', 'RBI', 'BB', 'OBP', 'TB', 'GDP', 'SH', 'SF', 'age_sqrd', 'BB_sqrd', 'RBI_sqrd', 'RBI_cube', 'H_sqrd']
# 0.542704948105
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:303: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
x = batdf[b1sig_cols]
y = batdf['log_salary']
lr = LinearRegression()
lr.fit(x,y)

# Fit the model to the full dataset


print('Fit score (R^2) is: %f'%lr.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(lr, y, lr.predict(x)))
print('Fit intercept is: %f'%lr.intercept_)
print('Mean of the target value is: %f'%y.mean())
lr.coef_
# Out:
# Fit score (R^2) is: 0.624932
# Adj R^2 is: 0.600203
# Fit intercept is: 0.977291
# Mean of the target value is: 14.892948
# array([  8.56945140e-01,   2.80262622e-03,  -1.21996834e-02,
#          1.45883601e-02,   4.41881793e-02,  -6.00816529e-03,
#          1.87941172e-02,   3.27102124e-02,  -1.28587636e+01,
#         -3.81662167e-03,   2.54956455e-02,  -8.73420595e-02,
#          3.69231411e-02,  -1.03416586e-02,  -1.57898882e-04,
#         -3.59245097e-04,   1.84321035e-06,  -3.26242255e-05])

# %%
pitchdf = pitchdf.dropna()
est=LinearRegression()
x = pitchdf.drop(['Salary','Name', 'log_salary'],1)
kf=KFold(n=len(x),n_folds=5,shuffle=True)
y = pitchdf['log_salary']
all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 

# get indices of corresponding train & test
for train,test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.05: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
            
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
p1sig_cols = sig_cols
print(p1sig_cols)
print(np.mean(all_scores))
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:303: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom
# ['Age', 'W', 'L', 'G', 'GS', 'CG', 'SHO', 'IP', 'H', 'R', 'ER', 'HR', 'BB', 'SO', 'WP', 'BF', 'BB9', 'SO/W', 'age_sqrd', 'w_sqrd', 'GS_sqrd', 'CG_sqrd', 'H_sqrd', 'H_cube', 'ER_sqrd', 'ER_cube', 'HR_sqrd', 'BB9_sqrd', 'SO/W_sqrd']
# 0.416930745623

# %%
x = pitchdf[p1sig_cols]
y = pitchdf['log_salary']
lr = LinearRegression()
lr.fit(x,y)

# Fit the model to the full dataset


print('Fit score (R^2) is: %f'%lr.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(lr, y, lr.predict(x)))
print('Fit intercept is: %f'%lr.intercept_)
print('Mean of the target value is: %f'%y.mean())
lr.coef_
# Out:
# Fit score (R^2) is: 0.636806
# Adj R^2 is: 0.583878
# Fit intercept is: -0.813583
# Mean of the target value is: 14.554615
# array([  9.18443887e-01,  -1.05625581e-02,   9.65948997e-02,
#          3.98477975e-03,  -1.48494551e-04,  -1.88451842e-01,
#         -9.12577760e-03,   5.45820876e-02,  -7.82581271e-03,
#          4.83884653e-02,  -7.09202818e-02,  -1.06055301e-02,
#          2.76976914e-03,   8.03466403e-03,   1.25284903e-02,
#         -2.19802384e-02,  -1.05757240e-01,   3.15652584e-02,
#         -1.22762570e-02,   3.72557156e-03,   1.35289752e-03,
#          5.12898966e-02,   1.24967951e-04,  -3.21441799e-07,
#          8.58183250e-04,  -4.52352296e-06,   5.94120307e-04,
#          2.19898572e-02,   4.61774836e-03])

# %%
x = batdf[b1sig_cols]
y = batdf['log_salary']
lr = LinearRegression()
fit = lr.fit(x,y)
y_predicted = fit.predict(x)
y_predicted

predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('log_salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %%
x = pitchdf[p1sig_cols]
y = pitchdf['log_salary']
lr = LinearRegression()
fit = lr.fit(x,y)
y_predicted = fit.predict(x)
y_predicted

predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('log_salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %% [markdown]
# # Refining the model
#
# ### Data
#
# As we can see above, there is a large portion of the data set that are being payed at or close to the MLB minimum.  I can reasonably assume that a large portion of these players are rookies and therefore being payed below their market value until their rookie contract expires.  That assumption makes them poor data points for this model and I will remove them.

# %%
batdf2 = batdf[batdf['Salary'] > 570000]
pitchdf2 = pitchdf[pitchdf['Salary'] > 560000]

# %%
print(len(batdf) - len(batdf2))
print(len(pitchdf) - len(pitchdf2))
# Out:
# 76
# 73

# %%
plt.plot(pitchdf2['log_salary'])

# %%
plt.hist(pitchdf2['log_salary'])
# Out:
# (array([  7.,  15.,  17.,  16.,  24.,  33.,  17.,  15.,   9.,   3.]),
#  array([ 13.24192261,  13.65191746,  14.06191231,  14.47190715,
#          14.881902  ,  15.29189685,  15.70189169,  16.11188654,
#          16.52188139,  16.93187624,  17.34187108]),
#  <a list of 10 Patch objects>)

# %%
from scipy import stats

lamb=stats.boxcox_normmax(pitchdf2.Salary, brack=(-1.9, 1.9))
print(lamb)
y_t=(np.power(pitchdf2.Salary,lamb)-1)/lamb

plt.hist(y_t);
# Out:
# 0.043640390279
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
plt.plot(y_t)

# %%
plt.plot(batdf2['log_salary'])

# %%
plt.hist(batdf2['log_salary'])
# Out:
# (array([ 15.,   9.,  17.,  16.,  21.,  25.,  33.,  25.,  32.,  23.]),
#  array([ 13.25724386,  13.64688446,  14.03652505,  14.42616565,
#          14.81580624,  15.20544684,  15.59508743,  15.98472803,
#          16.37436862,  16.76400922,  17.15364982]),
#  <a list of 10 Patch objects>)

# %%
from scipy import stats

lamb=stats.boxcox_normmax(batdf2.Salary, brack=(-1.9, 1.9))
print(lamb)
y_t=(np.power(batdf2.Salary,lamb)-1)/lamb

plt.hist(y_t);
# Out:
# 0.29428319749

# %%
plt.plot(y_t)

# %% [markdown]
# ### Batting

# %%
batdf2['salary_t'] = batdf2['Salary'] ** 0.29428319749
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
est=LinearRegression()
x = batdf2.drop(['Salary','Name', 'log_salary', 'salary_t'],1)
kf=KFold(n=len(x),n_folds=5,shuffle=True)
y = batdf2['salary_t']
all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 

# get indices of corresponding train & test
for train,test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.05: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
            
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
bsig_cols = sig_cols
print(bsig_cols)
print(np.mean(all_scores))
# Out:
# ['Age', 'PA', 'AB', 'R', 'H', 'RBI', 'BB', 'TB', 'GDP', 'SH']
# 0.344622898038
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:303: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
x = batdf2[bsig_cols]
y = batdf2['salary_t']
lr = LinearRegression()
lr.fit(x,y)

# Fit the model to the full dataset


print('Fit score (R^2) is: %f'%lr.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(lr, y, lr.predict(x)))
print('Fit intercept is: %f'%lr.intercept_)
print('Mean of the target value is: %f'%y.mean())
lr.coef_
# Out:
# Fit score (R^2) is: 0.413182
# Adj R^2 is: 0.396335
# Fit intercept is: -70.918876
# Mean of the target value is: 99.682194
# array([ 4.69640555,  0.02808617,  0.05869033,  0.11014756,  0.82717165,
#        -1.79106064])

# %%
x = batdf2[bsig_cols]
y = batdf2['salary_t']
lr = LinearRegression()
fit = lr.fit(x,y)
y_predicted = fit.predict(x)
y_predicted

predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('log_salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual salary_t')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %% [markdown]
# ### Pitching

# %%
est=LinearRegression()
x = pitchdf2.drop(['Salary','Name', 'log_salary'],1)
kf=KFold(n=len(x),n_folds=5,shuffle=True)
y = pitchdf2['log_salary']
all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 

# get indices of corresponding train & test
for train,test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.05: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
            
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
psig_cols = sig_cols
print(psig_cols)
print(np.mean(all_scores))
# Out:
# ['Age', 'W', 'L', 'G', 'GS', 'GF', 'CG', 'SHO', 'IP', 'H', 'R', 'ER', 'HR', 'BB', 'SO', 'HBP', 'WP', 'BF', 'HR9', 'BB9', 'SO/W']
# 0.346987843457
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:303: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
x = pitchdf2[psig_cols]
y = pitchdf2['log_salary']
lr = LinearRegression()
lr.fit(x,y)

# Fit the model to the full dataset


print('Fit score (R^2) is: %f'%lr.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(lr, y, lr.predict(x)))
print('Fit intercept is: %f'%lr.intercept_)
print('Mean of the target value is: %f'%y.mean())
lr.coef_
# Out:
# Fit score (R^2) is: 0.550065
# Adj R^2 is: 0.479553
# Fit intercept is: 12.766208
# Mean of the target value is: 15.185675
# array([ 0.0762938 ,  0.02498408,  0.04922814,  0.01162462,  0.15748806,
#         0.01546014,  0.19078479, -0.24079938, -0.02935582, -0.02101692,
#         0.01904622, -0.01561989,  0.05969295, -0.02675759,  0.00256542,
#        -0.04363632, -0.00325754,  0.00400838, -0.33645974,  0.11381456,
#         0.08188114])

# %%
x = pitchdf2[psig_cols]
y = pitchdf2['log_salary']
lr = LinearRegression()
fit = lr.fit(x,y)
y_predicted = fit.predict(x)
y_predicted

predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('log_salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %% [markdown]
# Manipulating the data appears to have worsened the overall fit of our model and its ability to predict unseen data.

# %% [markdown]
# ### Variables
#
# I will now look at the variables to see if they might need to be transformed at all.

# %% [markdown]
# ### Batting

# %%
def plot_approximation(est, ax, label=None):
    """Plot the approximation of ``est`` on axis ``ax``. """
    ax.scatter(X, y, s=100)
    ax.plot(x_plot, est.predict(x_plot[:, np.newaxis]), color='red', label=label)
    ax.set_ylim((10, 20))
    ax.set_xlim((0, 20))
    ax.set_ylabel('y')
    ax.set_xlabel('x')
    ax.legend(loc='upper right',frameon=True)

x_plot = np.linspace(0, 15, 100)

# %%
batdf.columns
# Out:
# Index(['Name', 'Salary', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB',
#        'GDP', 'HBP', 'SH', 'SF', 'IBB', 'intercept', 'log_salary'],
#       dtype='object')

# %%
for col in b1sig_cols:
    X = batdf[[col]]
    y = batdf['log_salary']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8)


    # Step through degrees from 0 to 9 and store the training and test (generalization) error.
    train_error = np.empty(10)
    test_error = np.empty(10)
    for degree in range(10):
        est = make_pipeline(PolynomialFeatures(degree), LinearRegression())
        est.fit(X_train, y_train)
        train_error[degree] = mean_squared_error(y_train, est.predict(X_train))
        test_error[degree] = mean_squared_error(y_test, est.predict(X_test))

    # Plot the training and test errors against degree
    plt.figure(figsize=(8,6))
    plt.plot(np.arange(10), train_error, color='green', label='train')
    plt.plot(np.arange(10), test_error, color='red', label='test')
    plt.ylim((0, 2))
    plt.ylabel('mean squared error of %r' %col)
    plt.xlabel('degree')
    plt.legend(loc='upper left')

# %% [markdown]
# According to the graphs above, the test error can be imporved by the transformation of the variables; Age, BB and OPS+.

# %%
batdf['age_sqrd'] = batdf['Age'] ** 2
batdf['BB_sqrd'] = batdf['BB'] ** 2
batdf['OPS+_sqrd'] = batdf['OPS+'] ** 2
batdf['RBI_sqrd'] = batdf['RBI'] ** 2
batdf['RBI_cube'] = batdf['RBI'] ** 3
batdf['H_sqrd'] = batdf['H'] ** 2

# %%
est=LinearRegression()
x = batdf.drop(['Salary','Name', 'log_salary'],1)
kf=KFold(n=len(x),n_folds=5,shuffle=True)
y = batdf['log_salary']
all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 

# get indices of corresponding train & test
for train,test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.02: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
            
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
bsig_cols = sig_cols
print(bsig_cols)
print(np.mean(all_scores))
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:303: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom
# ['Age', 'PA', 'AB', 'R', 'H', '2B', 'HR', 'RBI', 'BB', 'OBP', 'OPS+', 'TB', 'GDP', 'SH', 'SF', 'age_sqrd', 'BB_sqrd', 'OPS+_sqrd', 'RBI_sqrd', 'RBI_cube', 'H_sqrd']
# 0.576118654696

# %%
x = batdf[bsig_cols]
y = batdf['log_salary']
lr = LinearRegression()
lr.fit(x,y)

# Fit the model to the full dataset


print('Fit score (R^2) is: %f'%lr.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(lr, y, lr.predict(x)))
print('Fit intercept is: %f'%lr.intercept_)
print('Mean of the target value is: %f'%y.mean())
lr.coef_
# Out:
# Fit score (R^2) is: 0.635277
# Adj R^2 is: 0.606910
# Fit intercept is: 0.920779
# Mean of the target value is: 14.892948
# array([  8.91236245e-01,  -9.45484143e-04,  -4.42151279e-03,
#          1.31690546e-02,   4.32583133e-02,   2.70252523e-05,
#          1.31010403e-02,   2.60231160e-02,   3.41459490e-02,
#         -1.08876029e+01,  -3.28775613e-02,  -1.17556249e-02,
#          2.08252053e-02,  -9.38262787e-02,   4.01479346e-02,
#         -1.08938455e-02,  -1.87314493e-04,   1.79927971e-04,
#         -4.57112170e-04,   2.26827795e-06,  -3.57714759e-05])

# %%
y_predicted = lr.predict(x)
y_predicted

predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('log_salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %% [markdown]
# ### Pitching

# %%
for col in p1sig_cols:
    X = pitchdf[[col]]
    y = pitchdf['log_salary']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8)


    # Step through degrees from 0 to 9 and store the training and test (generalization) error.
    train_error = np.empty(10)
    test_error = np.empty(10)
    for degree in range(10):
        est = make_pipeline(PolynomialFeatures(degree), LinearRegression())
        est.fit(X_train, y_train)
        train_error[degree] = mean_squared_error(y_train, est.predict(X_train))
        test_error[degree] = mean_squared_error(y_test, est.predict(X_test))

    # Plot the training and test errors against degree
    plt.figure(figsize=(8,6))
    plt.plot(np.arange(10), train_error, color='green', label='train')
    plt.plot(np.arange(10), test_error, color='red', label='test')
    plt.ylim((0, 2))
    plt.ylabel('mean squared error of %r' %col)
    plt.xlabel('degree')
    plt.legend(loc='upper left')

# %%
pitchdf['age_sqrd'] = pitchdf['Age'] ** 2
pitchdf['w_sqrd'] = pitchdf['W'] ** 2
pitchdf['GS_sqrd'] = pitchdf['GS'] ** 2
pitchdf['GF_sqrd'] = pitchdf['GF'] ** 2
pitchdf['GF_cube'] = pitchdf['GF'] ** 3
pitchdf['GF_quad'] = pitchdf['GF'] ** 4
pitchdf['CG_sqrd'] = pitchdf['CG'] ** 2
pitchdf['H_sqrd'] = pitchdf['H'] ** 2
pitchdf['H_cube'] = pitchdf['H'] ** 3
pitchdf['ER_sqrd'] = pitchdf['ER'] ** 2
pitchdf['ER_cube'] = pitchdf['ER'] ** 3
pitchdf['HR_sqrd'] = pitchdf['HR'] ** 2
pitchdf['BB9_sqrd'] = pitchdf['BB9'] ** 2
pitchdf['SO/W_sqrd'] = pitchdf['SO/W'] ** 2

# %%
est=LinearRegression()
x = pitchdf.drop(['Salary','Name', 'log_salary'],1)
kf=KFold(n=len(x),n_folds=5,shuffle=True)
y = pitchdf['log_salary']
all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 

# get indices of corresponding train & test
for train,test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.00001: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
            
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
psig_cols = sig_cols
print(psig_cols)
print(np.mean(all_scores))
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:303: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom
# ['Age', 'W', 'L', 'GS', 'IP', 'H', 'R', 'ER', 'HR', 'SO', 'BF', 'age_sqrd', 'w_sqrd', 'GS_sqrd', 'H_sqrd', 'H_cube', 'ER_sqrd', 'ER_cube', 'HR_sqrd']
# 0.490266504046

# %%
x = pitchdf[psig_cols]
y = pitchdf['log_salary']
lr = LinearRegression()
lr.fit(x,y)

# Fit the model to the full dataset


print('Fit score (R^2) is: %f'%lr.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(lr, y, lr.predict(x)))
print('Fit intercept is: %f'%lr.intercept_)
print('Mean of the target value is: %f'%y.mean())
lr.coef_
# Out:
# Fit score (R^2) is: 0.623989
# Adj R^2 is: 0.589806
# Fit intercept is: -0.011040
# Mean of the target value is: 14.554615
# array([  8.90671539e-01,  -5.66321828e-03,   9.49777169e-02,
#         -1.94135854e-02,   4.62969340e-02,  -8.29537237e-03,
#          4.71892050e-02,  -9.61675666e-02,  -1.43747099e-02,
#          1.03545974e-02,  -1.86857577e-02,  -1.17862250e-02,
#          3.25561418e-03,   1.39122043e-03,   9.08961588e-05,
#         -2.30793429e-07,   1.40313165e-03,  -7.42878023e-06,
#          5.63272865e-04])

# %%
y_predicted = lr.predict(x)
y_predicted

predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('log_salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %% [markdown]
# # Regularization

# %% [markdown]
# In this section I will attempt to regularize my model using ridge, lasso, and ridgeCV which uses lasso ridge and elastic regularization.

# %% [markdown]
# ### Batting

# %%
x = batdf[bsig_cols]
y = batdf['log_salary']
alphas=[1e-5,1e-3,1e-1,1,100,10000]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

def make_estimator(est,alpha):
    est.alpha=alpha
    model = est.fit(X_train,y_train)
    mse=np.mean(y_test-model.predict(X_test))**2
    return mse
    
# Get scores
all_mse=[]    
for a in alphas:    
    all_mse.append(make_estimator(Ridge(),a))
    

#plot of model
plt.figure(figsize=(8,6))
plt.legend()
plt.plot(np.log10(alphas),all_mse)
plt.legend()
plt.xlabel('alphas')
plt.ylabel('MSE')
plt.show()

# %%
# A bit more involved approach: illustrated here with Lasso
kf = KFold(n=len(x), n_folds=5, shuffle=True)

all_scores=[]
alphas=[1e-5,1e-3,1e-1,0,1,100]


for train, test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    mse_score=[]
    for a in alphas:
        est=Lasso(alpha=a)
        est.fit(x_train,y_train)
        mse=np.mean((y_test-est.predict(x_test))**2)
        mse_score.append(mse)
    all_scores.append(mse_score)
#all_scores
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   app.launch_new_instance()
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:477: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)

# %%
# Which alpha is the best for our model ? Looks like alpha= 1
plt.figure(figsize=(8,6))
#plt.ylim(0,0.1)
plt.legend()
for i in range(5):
    plt.plot(all_scores[i],label = 'cv %s'%i)
plt.legend()
plt.xlabel('alphas')
plt.ylabel('MSE')
plt.show()

# %%
# Take a quick look at our strongest features
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

est=Lasso(alpha=1e-3)
est.fit(X_train,y_train)
est.alpha


zipped=zip(x.columns,est.coef_)
features=sorted(zipped,key = lambda t: t[1],reverse=True)
features[:]
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# [('Age', 0.2501220388321358),
#  ('GDP', 0.026894435532444954),
#  ('R', 0.017902698135659274),
#  ('H', 0.012954746980541098),
#  ('BB', 0.011144771346095005),
#  ('AB', 0.0027095790293050646),
#  ('RBI', 0.00067228391529327637),
#  ('TB', -0.0042008258069931009),
#  ('PA', -0.005379299363238086),
#  ('SH', -0.046158974969145686)]

# %%
print(est.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(est, y, est.predict(x)))
# Out:
# 0.588354278859
# Adj R^2 is: 0.573705

# %%
# As we saw before, here is our baseline r^2 score
lr=LinearRegression()
#x = batdf.drop(['Name', 'Salary','log_salary'])
#y = batdf['log_salary']
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3)

lr.fit(xtrain, ytrain)
print(lr.score(xtest, ytest))
print('Adj R^2 is: %f'%adj_r2_score(lr, ytest, lr.predict(xtest)))
# Out:
# 0.687344797625
# Adj R^2 is: 0.646740

# %%
rcv = RidgeCV(cv=10)
rcv.fit(x, y)
print(rcv.score(xtest, ytest))
print('Adj R^2 is: %f'%adj_r2_score(rcv, ytest, rcv.predict(xtest)))
# Out:
# 0.693189580708
# Adj R^2 is: 0.653344

# %%
zipped=zip(x.columns,rcv.coef_)
features=sorted(zipped,key = lambda t: np.abs(t[1]),reverse=True)
features[:10]
# Out:
# [('Age', 0.25172594737004467),
#  ('SH', -0.086001770878210634),
#  ('GDP', 0.024803306850153004),
#  ('H', 0.012730094520753748),
#  ('R', 0.012508447329343924),
#  ('TB', -0.0048440040983675952),
#  ('BB', 0.0039016826095295788),
#  ('RBI', 0.0018013931696502442),
#  ('PA', -0.0017212967983460195),
#  ('AB', 0.00053178146721953243)]

# %%
#couldn't figure out why stats model would give me very high R^2 and adj R^2 so I decided not to use it at all.
model = sm.OLS(y,x)

fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_salary   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     5099.
# Date:                Thu, 01 Feb 2018   Prob (F-statistic):          4.23e-312
# Time:                        22:34:40   Log-Likelihood:                -444.53
# No. Observations:                 292   AIC:                             909.1
# Df Residuals:                     282   BIC:                             945.8
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.4313      0.008     52.149      0.000       0.415       0.448
# PA            -0.0106      0.015     -0.703      0.483      -0.040       0.019
# AB             0.0133      0.015      0.872      0.384      -0.017       0.043
# R              0.0082      0.009      0.885      0.377      -0.010       0.026
# H              0.0079      0.007      1.113      0.267      -0.006       0.022
# RBI            0.0005      0.007      0.071      0.943      -0.014       0.015
# BB             0.0101      0.016      0.633      0.527      -0.021       0.042
# TB            -0.0003      0.005     -0.056      0.955      -0.011       0.010
# GDP            0.0006      0.018      0.036      0.971      -0.034       0.036
# SH            -0.0022      0.052     -0.043      0.966      -0.105       0.100
# ==============================================================================
# Omnibus:                        3.023   Durbin-Watson:                   1.675
# Prob(Omnibus):                  0.221   Jarque-Bera (JB):                3.151
# Skew:                          -0.090   Prob(JB):                        0.207
# Kurtosis:                       3.476   Cond. No.                         573.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_predicted = rcv.predict(x)
predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)
plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('log_salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');

# %% [markdown]
# ### Pitching

# %%
x = pitchdf[psig_cols]
y = pitchdf['log_salary']
alphas=[1e-5,1e-3,1e-1,1,100,10000]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# Get scores
all_mse=[]    
for a in alphas:    
    all_mse.append(make_estimator(Ridge(),a))
    

#plot of model
plt.figure(figsize=(8,6))
plt.legend()
plt.plot(np.log10(alphas),all_mse)
plt.legend()
plt.xlabel('alphas')
plt.ylabel('MSE')
plt.show()

# %%
# A bit more involved approach: illustrated here with Lasso
kf = KFold(n=len(x), n_folds=5, shuffle=True)

all_scores=[]
alphas=[1e-5,1e-3,1e-1,0,1,100]


for train, test in kf:
    x_train=x.iloc[train]
    y_train=y.iloc[train]
    x_test=x.iloc[test]
    y_test=y.iloc[test]
    mse_score=[]
    for a in alphas:
        est=Lasso(alpha=a)
        est.fit(x_train,y_train)
        mse=np.mean((y_test-est.predict(x_test))**2)
        mse_score.append(mse)
    all_scores.append(mse_score)
#all_scores
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   app.launch_new_instance()
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:477: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)

# %%
# Which alpha is the best for our model ? Looks like alpha= 1
plt.figure(figsize=(8,6))
#plt.ylim(0,0.1)
plt.legend()
for i in range(5):
    plt.plot(all_scores[i],label = 'cv %s'%i)
plt.legend()
plt.xlabel('alphas')
plt.ylabel('MSE')
plt.show()

# %%
# Take a quick look at our strongest features
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

est=Lasso(alpha=0)
est.fit(X_train,y_train)
est.alpha


zipped=zip(x.columns,est.coef_)
features=sorted(zipped,key = lambda t: t[1],reverse=True)
features[:]
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   """
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:477: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# [('Age', 0.18610616266131833),
#  ('BB9', 0.1703422704796034),
#  ('CG', 0.14607760167151329),
#  ('SO/W', 0.12066027954210293),
#  ('GS', 0.070926673592740075),
#  ('L', 0.070605706870457655),
#  ('HR', 0.04500472166913972),
#  ('SHO', 0.03835306697506434),
#  ('R', 0.024717582787674889),
#  ('GF', 0.015214432163321103),
#  ('SO', 0.0092642511962110676),
#  ('H', 0.007737074723221409),
#  ('W', 0.0072417977881748946),
#  ('IP', 0.0036342424675596956),
#  ('WP', 0.0018849571425901442),
#  ('G', -0.0038534864974556411),
#  ('BF', -0.0075989334818475094),
#  ('BB', -0.018244910279921631),
#  ('HBP', -0.019293159312134937),
#  ('ER', -0.025174452802780245),
#  ('HR9', -0.41191423987551723)]

# %%
print(est.score(x,y))
print('Adj R^2 is: %f'%adj_r2_score(est, y, est.predict(x)))
# Out:
# 0.58641852931
# Adj R^2 is: 0.544461

# %%
# As we saw before, here is our baseline r^2 score
lr=LinearRegression()
#x = batdf.drop(['Name', 'Salary','log_salary'])
#y = batdf['log_salary']
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3)

lr.fit(xtrain, ytrain)
print(lr.score(xtest, ytest))
print('Adj R^2 is: %f'%adj_r2_score(lr, ytest, lr.predict(xtest)))
# Out:
# 0.633160795904
# Adj R^2 is: 0.469254

# %%
rcv = RidgeCV(cv=10)
rcv.fit(x, y)
print(rcv.score(xtest, ytest))
print('Adj R^2 is: %f'%adj_r2_score(rcv, ytest, rcv.predict(xtest)))
# Out:
# 0.697630084265
# Adj R^2 is: 0.562529

# %%
zipped=zip(x.columns,rcv.coef_)
features=sorted(zipped,key = lambda t: np.abs(t[1]),reverse=True)
features[:10]
# Out:
# [('HR9', -0.21984373213569081),
#  ('Age', 0.17535055519164822),
#  ('BB9', 0.15906346264270987),
#  ('GS', 0.10581697996574066),
#  ('SO/W', 0.092166726845355304),
#  ('L', 0.066547436440127603),
#  ('HR', 0.042968867354980664),
#  ('CG', 0.042301244727726575),
#  ('R', 0.038743278428874643),
#  ('SHO', 0.03855940883986559)]

# %%
y_predicted = rcv.predict(x)

# %%
predictdf = pd.DataFrame(y_predicted,y)

sns.jointplot(y, y_predicted)

plt.ylabel('Predicted outcome')
# Out:
# Text(336.971,0.5,'Predicted outcome')

# %%
plt.scatter(range(1,len(y_predicted)+1),y)
plt.scatter(range(1,len(y_predicted)+1), y_predicted, color='red')
plt.xlabel('Player index')
plt.ylabel('log_salary')
plt.title('y_predicted vs. y')
plt.legend()

# %%
yp = y_predicted
res = y-yp
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5))
ax[0].scatter(y, yp, edgecolors=(0, 0, 0))
ax[0].set_xlabel('Actual log_salary')
ax[0].set_ylabel('Predicted')
ax[0].set_title('Prediction vs. Actual Value',fontweight='bold')

ax[1].hist(res,bins=20);
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Count')
ax[1].set_title('Histogram of Residuals',fontweight='bold');
