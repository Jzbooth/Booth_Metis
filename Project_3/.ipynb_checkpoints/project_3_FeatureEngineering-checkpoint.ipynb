# %%
import pandas as pd
from collections import defaultdict
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
import re
from patsy import dmatrices
from sklearn.metrics import roc_auc_score
from sklearn import linear_model as lm
from sklearn import cross_validation
from sklearn import metrics
from sklearn.metrics import confusion_matrix
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import roc_curve, auc
from IPython.display import Image

from sklearn import datasets
from sklearn.decomposition import PCA
import pickle
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
with open("ccdf.pkl", 'rb') as picklefile: 
    ccdf = pickle.load(picklefile)

# %%
ccdf
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    1          1         0   24      2      2     -1
# 1          2     120000    1          1         1   26     -1      2      0
# 2          3      90000    1          1         1   34      0      0      0
# 3          4      50000    1          1         0   37      0      0      0
# 4          5      50000    0          1         0   57     -1      0     -1
# 5          6      50000    0          0         1   37      0      0      0
# 6          7     500000    0          0         1   29      0      0      0
# 7          8     100000    1          1         1   23      0     -1     -1
# 8          9     140000    1          2         0   28      0      0      2
# 9         10      20000    0          2         1   35     -2     -2     -2
# 10        11     200000    1          2         1   34      0      0      2
# 11        12     260000    1          0         1   51     -1     -1     -1
# 12        13     630000    1          1         1   41     -1      0     -1
# 13        14      70000    0          1         1   30      1      2      2
# 14        15     250000    0          0         1   29      0      0      0
# 15        17      20000    0          0         1   24      0      0      2
# 16        18     320000    0          0         0   49      0      0      0
# 17        19     360000    1          0         0   49      1     -2     -2
# 18        20     180000    1          0         1   29      1     -2     -2
# 19        21     130000    1          2         1   39      0      0      0
# 20        22     120000    1          1         0   39     -1     -1     -1
# 21        23      70000    1          1         1   26      2      0      0
# 22        24     450000    1          0         0   40     -2     -2     -2
# 23        25      90000    0          0         1   23      0      0      0
# 24        26      50000    0          2         1   23      0      0      0
# 25        27      60000    0          0         1   27      1     -2     -1
# 26        28      50000    1          2         1   30      0      0      0
# 27        29      50000    1          2         0   47     -1     -1     -1
# 28        30      50000    0          0         1   26      0      0      0
# 29        31     230000    1          0         1   27     -1     -1     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29133  29971     360000    0          0         0   34     -1     -1     -1
# 29134  29972      80000    0          2         0   36      0      0      0
# 29135  29973     190000    0          0         0   37      0      0      0
# 29136  29974     230000    0          1         0   35      1     -2     -2
# 29137  29975      50000    0          1         0   37      1      2      2
# 29138  29976     220000    0          1         0   41      0      0     -1
# 29139  29977      40000    0          1         1   47      2      2      3
# 29140  29978     420000    0          0         1   34      0      0      0
# 29141  29979     310000    0          1         0   39      0      0      0
# 29142  29980     180000    0          0         0   32     -2     -2     -2
# 29143  29981      50000    0          2         1   42      0      0      0
# 29144  29982      50000    0          1         0   44      1      2      2
# 29145  29983      90000    0          1         0   36      0      0      0
# 29146  29984      20000    0          1         0   44     -2     -2     -2
# 29147  29985      30000    0          1         1   38     -1     -1     -2
# 29148  29986     240000    0          0         1   30     -2     -2     -2
# 29149  29987     360000    0          0         1   35     -1     -1     -2
# 29150  29988     130000    0          0         1   34      0      0      0
# 29151  29989     250000    0          0         0   34      0      0      0
# 29152  29990     150000    0          0         1   35     -1     -1     -1
# 29153  29991     140000    0          1         0   41      0      0      0
# 29154  29992     210000    0          1         0   34      3      2      2
# 29155  29993      10000    0          2         0   43      0      0      0
# 29156  29994     100000    0          0         1   38      0     -1     -1
# 29157  29995      80000    0          1         1   34      2      2      2
# 29158  29996     220000    0          2         0   39      0      0      0
# 29159  29997     150000    0          2         1   43     -1     -1     -1
# 29160  29998      30000    0          1         1   37      4      3      2
# 29161  29999      80000    0          2         0   41      1     -1      0
# 29162  30000      50000    0          1         0   46      0      0      0
#
#        PAY_4    ...     PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0         -1    ...            0       689         0         0         0
# 1          0    ...            0      1000      1000      1000         0
# 2          0    ...         1518      1500      1000      1000      1000
# 3          0    ...         2000      2019      1200      1100      1069
# 4          0    ...         2000     36681     10000      9000       689
# 5          0    ...         2500      1815       657      1000      1000
# 6          0    ...        55000     40000     38000     20239     13750
# 7          0    ...          380       601         0       581      1687
# 8          0    ...         3329         0       432      1000      1000
# 9         -2    ...            0         0         0     13007      1122
# 10         0    ...         2306        12        50       300      3738
# 11        -1    ...        21818      9966      8583     22301         0
# 12        -1    ...         1000      6500      6500      6500      2870
# 13         0    ...         3200         0      3000      3000      1500
# 14         0    ...         3000      3000      3000      3000      3000
# 15         2    ...         3200         0      1500         0      1650
# 16        -1    ...        10358     10000     75940     20000    195599
# 17        -2    ...            0         0         0         0         0
# 18        -2    ...            0         0         0         0         0
# 19         0    ...         3000      1537      1000      2000       930
# 20        -1    ...          316       316         0       632       316
# 21         2    ...         2007      3582         0      3601         0
# 22        -2    ...        19428      1473       560         0         0
# 23        -1    ...         5757         0      5398      1200      2045
# 24         0    ...         1973      1426      1001      1432      1062
# 25        -1    ...            0      1000         0       500         0
# 26         0    ...         1300      1300      1000      1500      1000
# 27        -1    ...         3415      3421      2044     30430       257
# 28         0    ...         1500      1500      1000      1000      1600
# 29        -1    ...        17270     13281     15339     14307     37292
# ...      ...    ...          ...       ...       ...       ...       ...
# 29133      0    ...        52951     64535      8907        53     19584
# 29134      0    ...         2395      2500      2530      2556      3700
# 29135      0    ...         2000      3869     25128     10115    148482
# 29136     -2    ...            0         0         0         0         0
# 29137      2    ...            0      3000         0         0      1000
# 29138     -1    ...         8840      6643      5924      1759      1824
# 29139      2    ...         4000         0      2000         0      3520
# 29140      0    ...         7000      7000      5500      5500      5600
# 29141      0    ...        10029      9218     10029      8049      8040
# 29142     -2    ...            0         0         0         0         0
# 29143      0    ...        10000      4000      5000      3000      4500
# 29144      2    ...         2300      1700         0       517       503
# 29145      0    ...         1500      1500      1500      1200      2500
# 29146     -2    ...         2890      2720      2890      9263      1824
# 29147     -1    ...          923      2977      1999      3057      3319
# 29148     -2    ...            0         0         0         0         0
# 29149     -2    ...            0         0         0         0         0
# 29150      0    ...         3000      2000     93000      4000      5027
# 29151      0    ...        65000      8800      9011      6000      7000
# 29152     -1    ...         9054         0       783         0         0
# 29153      0    ...         6000      7000      4228      1505      2000
# 29154      2    ...            0         0         0         0         0
# 29155     -2    ...         2000         0         0         0         0
# 29156      0    ...         2000    111784      4000      3000      2000
# 29157      2    ...         7000      3500         0      7000         0
# 29158      0    ...         8500     20000      5003      3047      5000
# 29159     -1    ...         1837      3526      8998       129         0
# 29160     -1    ...            0         0     22000      4200      2000
# 29161      0    ...        85900      3409      1178      1926     52964
# 29162      0    ...         2078      1800      1430      1000      1000
#
#        PAY_AMT6  default  HIGHSCHOOL  UNIVERSITY  GRADUATE
# 0             0        1           0           1         0
# 1          2000        1           0           1         0
# 2          5000        0           0           1         0
# 3          1000        0           0           1         0
# 4           679        0           0           1         0
# 5           800        0           0           0         1
# 6         13770        0           0           0         1
# 7          1542        0           0           1         0
# 8          1000        0           1           0         0
# 9             0        0           1           0         0
# 10           66        0           1           0         0
# 11         3640        0           0           0         1
# 12            0        0           0           1         0
# 13            0        1           0           1         0
# 14         3000        0           0           0         1
# 15            0        1           0           0         1
# 16        50000        0           0           0         1
# 17            0        0           0           0         1
# 18            0        0           0           0         1
# 19        33764        0           1           0         0
# 20            0        1           0           1         0
# 21         1820        1           0           1         0
# 22         1128        1           0           0         1
# 23         2000        0           0           0         1
# 24          997        0           1           0         0
# 25         1000        1           0           0         1
# 26         1012        0           1           0         0
# 27            0        0           1           0         0
# 28            0        0           0           0         1
# 29            0        0           0           0         1
# ...         ...      ...         ...         ...       ...
# 29133     16080        0           0           0         1
# 29134      3000        0           1           0         0
# 29135      4800        0           0           0         1
# 29136         0        1           0           1         0
# 29137      1000        1           0           1         0
# 29138      7022        0           0           1         0
# 29139         0        1           0           1         0
# 29140      5000        0           0           0         1
# 29141     10059        0           0           1         0
# 29142         0        0           0           0         1
# 29143      2000        0           1           0         0
# 29144       585        0           0           1         0
# 29145         0        1           0           1         0
# 29146      1701        0           0           1         0
# 29147      1000        0           0           1         0
# 29148         0        0           0           0         1
# 29149         0        0           0           0         1
# 29150      4005        0           0           0         1
# 29151      6009        0           0           0         1
# 29152         0        0           0           0         1
# 29153      2000        0           0           1         0
# 29154         0        1           0           1         0
# 29155         0        0           1           0         0
# 29156      2000        0           0           0         1
# 29157      4000        1           0           1         0
# 29158      1000        0           1           0         0
# 29159         0        0           1           0         0
# 29160      3100        1           0           1         0
# 29161      1804        1           1           0         0
# 29162      1000        1           0           1         0
#
# [29163 rows x 28 columns]

# %%
ccdf = ccdf.drop('HIGHSCHOOL',1)

# %%
ccdf3 = ccdf.drop(['ID', 'EDUCATION'],1)

# %%
ccdf3.to_pickle('ccdf3.pkl')

# %%
#Here I will attempt to convert my pay amount and bill amount features into a more useful feature.
#I will do this by taking the difference from bill amount and pay amount at each interval then fit a line to it and 
#use the slope


#will take the differences and return the slope.
def getslope(data):
    X = np.arange(len(data))
    lr = LinearRegression()
    fit = lr.fit(X.reshape(-1, 1),data)
    slope = fit.coef_
    return(slope)


#will take a df consisting of just pay amt 1-6 and bill amt 1-6 and return their differences in an array
def getdata(df):
    i = 0
    df['slope'] = 0
    while i < len(df):
        differences = []
        k = 0
        while k < 5:
            differences.append(df.loc[i][k] - df.loc[i][k+6])
            k = k + 1
            if k == 5:
                df['slope'][i] = getslope(differences)
        i = i + 1
    return df

# %%
payhist = ccdf.drop(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2','PAY_3','PAY_4', 'PAY_5', 'PAY_6', 'default', 'UNIVERSITY', 'GRADUATE'],1)

# %%
payhist
# Out:
#        BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# 0           3913       3102        689          0          0          0
# 1           2682       1725       2682       3272       3455       3261
# 2          29239      14027      13559      14331      14948      15549
# 3          46990      48233      49291      28314      28959      29547
# 4           8617       5670      35835      20940      19146      19131
# 5          64400      57069      57608      19394      19619      20024
# 6         367965     412023     445007     542653     483003     473944
# 7          11876        380        601        221       -159        567
# 8          11285      14096      12108      12211      11793       3719
# 9              0          0          0          0      13007      13912
# 10         11073       9787       5535       2513       1828       3731
# 11         12261      21670       9966       8517      22287      13668
# 12         12137       6500       6500       6500       6500       2870
# 13         65802      67369      65701      66782      36137      36894
# 14         70887      67060      63561      59696      56875      55512
# 15         15376      18010      17428      18338      17905      19104
# 16        253286     246536     194663      70074       5856     195599
# 17             0          0          0          0          0          0
# 18             0          0          0          0          0          0
# 19         38358      27688      24489      20616      11802        930
# 20           316        316        316          0        632        316
# 21         41087      42445      45020      44006      46905      46012
# 22          5512      19420       1473        560          0          0
# 23          4744       7070          0       5398       6360       8292
# 24         47620      41810      36023      28967      29829      30046
# 25          -109       -425        259        -57        127       -189
# 26         22541      16138      17163      17878      18931      19617
# 27           650       3415       3416       2040      30430        257
# 28         15329      16575      17496      17907      18375      11400
# 29         16646      17265      13266      15339      14307      36923
# ...          ...        ...        ...        ...        ...        ...
# 29133      33654      52686      64069      49005       8676      19487
# 29134      65554      66858      68279      69674      71070      73612
# 29135      21628      20893       5869      29223      19616     148482
# 29136          0          0          0          0          0          0
# 29137      10904       9316       4328       2846       1585       1324
# 29138      45075       8840       1369       5924       1759       1824
# 29139      52358      54892      53415      51259      47151      46934
# 29140     131939     136721     140011     141695     144839     147954
# 29141     238973     237196     233854     219409     216540     210675
# 29142          0          0          0          0          0          0
# 29143      43998      49123      49397      50360      19971      19694
# 29144      38671      36772      33101      28192      22676      14647
# 29145       7752       9112      10306      11328      12036      14329
# 29146       1822       2872       2712       2882       9235       1719
# 29147        315        923       2939       1993       1907       3319
# 29148          0          0          0          0          0          0
# 29149       2220          0          0          0          0          0
# 29150      23292      14077      15546     108047      93708      97353
# 29151     279640     252913     243075     245750     175005     179687
# 29152       3425       9009         -3        780          0          0
# 29153     138325     137142     139110     138262      49675      46121
# 29154       2500       2500       2500       2500       2500       2500
# 29155       8802      10400          0          0          0          0
# 29156       3042       1427     102996      70626      69473      55004
# 29157      72557      77708      79384      77519      82607      81158
# 29158     188948     192815     208365      88004      31237      15980
# 29159       1683       1828       3502       8979       5190          0
# 29160       3565       3356       2758      20878      20582      19357
# 29161      -1645      78379      76304      52774      11855      48944
# 29162      47929      48905      49764      36535      32428      15313
#
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0             0       689         0         0         0         0
# 1             0      1000      1000      1000         0      2000
# 2          1518      1500      1000      1000      1000      5000
# 3          2000      2019      1200      1100      1069      1000
# 4          2000     36681     10000      9000       689       679
# 5          2500      1815       657      1000      1000       800
# 6         55000     40000     38000     20239     13750     13770
# 7           380       601         0       581      1687      1542
# 8          3329         0       432      1000      1000      1000
# 9             0         0         0     13007      1122         0
# 10         2306        12        50       300      3738        66
# 11        21818      9966      8583     22301         0      3640
# 12         1000      6500      6500      6500      2870         0
# 13         3200         0      3000      3000      1500         0
# 14         3000      3000      3000      3000      3000      3000
# 15         3200         0      1500         0      1650         0
# 16        10358     10000     75940     20000    195599     50000
# 17            0         0         0         0         0         0
# 18            0         0         0         0         0         0
# 19         3000      1537      1000      2000       930     33764
# 20          316       316         0       632       316         0
# 21         2007      3582         0      3601         0      1820
# 22        19428      1473       560         0         0      1128
# 23         5757         0      5398      1200      2045      2000
# 24         1973      1426      1001      1432      1062       997
# 25            0      1000         0       500         0      1000
# 26         1300      1300      1000      1500      1000      1012
# 27         3415      3421      2044     30430       257         0
# 28         1500      1500      1000      1000      1600         0
# 29        17270     13281     15339     14307     37292         0
# ...         ...       ...       ...       ...       ...       ...
# 29133     52951     64535      8907        53     19584     16080
# 29134      2395      2500      2530      2556      3700      3000
# 29135      2000      3869     25128     10115    148482      4800
# 29136         0         0         0         0         0         0
# 29137         0      3000         0         0      1000      1000
# 29138      8840      6643      5924      1759      1824      7022
# 29139      4000         0      2000         0      3520         0
# 29140      7000      7000      5500      5500      5600      5000
# 29141     10029      9218     10029      8049      8040     10059
# 29142         0         0         0         0         0         0
# 29143     10000      4000      5000      3000      4500      2000
# 29144      2300      1700         0       517       503       585
# 29145      1500      1500      1500      1200      2500         0
# 29146      2890      2720      2890      9263      1824      1701
# 29147       923      2977      1999      3057      3319      1000
# 29148         0         0         0         0         0         0
# 29149         0         0         0         0         0         0
# 29150      3000      2000     93000      4000      5027      4005
# 29151     65000      8800      9011      6000      7000      6009
# 29152      9054         0       783         0         0         0
# 29153      6000      7000      4228      1505      2000      2000
# 29154         0         0         0         0         0         0
# 29155      2000         0         0         0         0         0
# 29156      2000    111784      4000      3000      2000      2000
# 29157      7000      3500         0      7000         0      4000
# 29158      8500     20000      5003      3047      5000      1000
# 29159      1837      3526      8998       129         0         0
# 29160         0         0     22000      4200      2000      3100
# 29161     85900      3409      1178      1926     52964      1804
# 29162      2078      1800      1430      1000      1000      1000
#
# [29163 rows x 12 columns]

# %%
payhist = getdata(payhist)

# %%
ccdf['slope'] = payhist['slope']

# %%
# barplot of marriage rating grouped by affair (True or False)
pd.crosstab(ccdf.EDUCATION, ccdf.default.astype(bool)).plot(kind='bar')
plt.title('Education level Distribution by Default status')
plt.xlabel('Education level')
plt.ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
# barplot of marriage rating grouped by affair (True or False)
pd.crosstab(ccdf.SEX, ccdf.default.astype(bool)).plot(kind='bar')
plt.title('Sex Distribution by Default status')
plt.xlabel('Sex')
plt.ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
# barplot of marriage rating grouped by affair (True or False)
pd.crosstab(ccdf.AGE, ccdf.default.astype(bool)).plot(kind='bar')
plt.title('Age Distribution by Default status')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
ccdf2 = ccdf.drop(['ID','EDUCATION', 'PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6','PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6'],1)

# %%
#Save the new data frame to a pickle file so we can easily bring it into other notebooks where we will model.

# %%
ccdf2.to_pickle('ccdf2.pkl')

# %%
#Now that we have done a bit of feature engineering we need to take a look at the class balance.

ccdf2.groupby('default')['default'].count()
# Out:
# default
# 0    22649
# 1     6514
# Name: default, dtype: int64

# %%
plt.figure(figsize = (8,5))
plt.hist(ccdf2['default'], bins = 3 , align = 'left');
plt.xticks([0,.675], ['no default', 'default']);
plt.ylabel('Count');

# %%
#Obvoisuly there is a little bit of an imbalance in our classes.  To remedy this we will try both oversampling and
# undersampling methods.
from sklearn.utils import resample

# %%
X_train, X_test, y_train, y_test = train_test_split(ccdf.drop('default',1), ccdf.default, test_size=.5, random_state=1234)

# %%
y_test.value_counts()
# Out:
# 0    11363
# 1     3219
# Name: default, dtype: int64

# %%
y_train.value_counts()
# Out:
# 0    11286
# 1     3295
# Name: default, dtype: int64

# %%
X_train['default'] = y_train
X_test['default'] = y_test

# %%
df_majority = X_train[X_train.default==0]
df_minority = X_train[X_train.default==1]

# %%
# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=len(df_majority),    # to match majority class
                                 random_state=123) # reproducible results
 
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
 
# Display new class counts
df_upsampled.default.value_counts()
# Out:
# 1    11286
# 0    11286
# Name: default, dtype: int64

# %%
# Separate majority and minority classes
df_majority2 = X_test[X_test.default==0]
df_minority2 = X_test[X_test.default==1]
 
# Upsample minority class
df_minority_upsampled2 = resample(df_minority2, 
                                 replace=True,     # sample with replacement
                                 n_samples=len(df_majority2),    # to match majority class
                                 random_state=123) # reproducible results
 
# Combine majority class with upsampled minority class
df_upsampled2 = pd.concat([df_majority2, df_minority_upsampled2])
 
# Display new class counts
df_upsampled2.default.value_counts()
# Out:
# 1    11363
# 0    11363
# Name: default, dtype: int64

# %%
df_upsampled.to_pickle('ccdf_upsampled_train.pkl')
df_upsampled2.to_pickle('ccdf_upsampled_test.pkl')

# %%
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # sample without replacement
                                 n_samples=len(df_minority),     # to match minority class
                                 random_state=123) # reproducible results
 
# Combine minority class with downsampled majority class
df_downsampled = pd.concat([df_majority_downsampled, df_minority])
 
# Display new class counts
df_downsampled.default.value_counts()
# Out:
# 1    6514
# 0    6514
# Name: default, dtype: int64

# %%
df_downsampled.to_pickle('ccdf_downsampled.pkl')

# %%
plt.figure(figsize = (8,5))
plt.hist(df_downsampled['default'], bins = 3 , align = 'left');
plt.xticks([0,.675], ['no default', 'default']);
plt.ylabel('Count');

# %%
plt.figure(figsize = (8,5))
plt.hist(df_upsampled['default'], bins = 3 , align = 'left');
plt.xticks([0,.675], ['no default', 'default']);
plt.ylabel('Count');

# %%
ccdf2
# Out:
#        LIMIT_BAL  SEX  MARRIAGE  AGE  default  UNIVERSITY  GRADUATE   slope
# 0          20000    1         0   24        1           1         0   -1023
# 1         120000    1         1   26        1           1         0     309
# 2          90000    1         1   34        0           1         0   -2674
# 3          50000    1         0   37        0           1         0   -5320
# 4          50000    0         0   57        0           1         0    6663
# 5          50000    0         1   37        0           0         1  -12342
# 6         500000    0         1   29        0           0         1   46296
# 7         100000    1         1   23        0           1         0   -2682
# 8         140000    1         0   28        0           0         0     278
# 9          20000    0         1   35        0           0         0    1076
# 10        200000    1         1   34        0           0         0   -2891
# 11        260000    1         1   51        0           0         1    3820
# 12        630000    1         1   41        0           1         0   -1501
# 13         70000    0         1   30        1           1         0   -5951
# 14        250000    0         1   29        0           0         1   -3538
# 15         20000    0         1   24        1           0         1     848
# 16        320000    0         0   49        0           0         1 -105180
# 17        360000    1         0   49        0           0         1       0
# 18        180000    1         1   29        0           0         1       0
# 19        130000    1         1   39        0           0         0   -5650
# 20        120000    1         0   39        1           1         0       0
# 21         70000    1         1   26        1           1         0    1719
# 22        450000    1         0   40        1           0         1    1044
# 23         90000    0         1   23        0           0         1     778
# 24         50000    0         1   23        0           0         0   -4660
# 25         60000    0         1   27        1           0         1     134
# 26         50000    1         1   30        0           0         0    -507
# 27         50000    1         0   47        0           0         0    3749
# 28         50000    0         1   26        0           0         1     772
# 29        230000    1         1   27        0           0         1   -4767
# ...          ...  ...       ...  ...      ...         ...       ...     ...
# 29133     360000    0         0   34        0           0         1    7757
# 29134      80000    0         0   36        0           0         0    1118
# 29135     190000    0         0   37        0           0         1  -29490
# 29136     230000    0         0   35        1           1         0       0
# 29137      50000    0         0   37        1           1         0   -2410
# 29138     220000    0         0   41        0           1         0   -7063
# 29139      40000    0         1   47        1           1         0   -1308
# 29140     420000    0         1   34        0           0         1    3507
# 29141     310000    0         0   39        0           1         0   -5750
# 29142     180000    0         0   32        0           0         1       0
# 29143      50000    0         1   42        0           0         0   -3481
# 29144      50000    0         0   44        0           1         0   -3579
# 29145      90000    0         0   36        1           1         0     908
# 29146      20000    0         0   44        0           1         0    1042
# 29147      30000    0         1   38        0           1         0     -61
# 29148     240000    0         1   30        0           0         1       0
# 29149     360000    0         1   35        0           0         1    -444
# 29150     130000    0         1   34        0           0         1   22874
# 29151     250000    0         0   34        0           0         1   -9763
# 29152     150000    0         1   35        0           0         1     302
# 29153     140000    0         0   41        0           1         0  -16268
# 29154     210000    0         0   34        1           1         0       0
# 29155      10000    0         0   43        0           0         0   -2400
# 29156     100000    0         1   38        0           0         1   31084
# 29157      80000    0         1   34        1           1         0    3041
# 29158     220000    0         0   39        0           0         0  -39628
# 29159     150000    0         1   43        0           0         0    2123
# 29160      30000    0         1   37        1           1         0    4335
# 29161      80000    0         0   41        1           0         0    6875
# 29162      50000    0         0   46        1           1         0   -4041
#
# [29163 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(ccdf.drop('default', 1), ccdf.default, test_size=0.3, random_state=42)
rfc = DecisionTreeClassifier()
model = rfc.fit(X_train, y_train)
y_rfc_prob = model.predict_proba(X_test)[:,1]
roc_auc_score(y_test, y_rfc_prob)
# Out:
# 0.61256760216871409

# %%
X_train, X_test, y_train, y_test = train_test_split(ccdf2.drop('default', 1), ccdf2.default, test_size=0.3, random_state=42)
rfc = DecisionTreeClassifier()
model = rfc.fit(X_train, y_train)
y_rfc_prob = rfc.predict_proba(X_test)[:,1]
print(roc_auc_score(y_test, y_rfc_prob))

fpr, tpr,_ = roc_curve(y_test, y_rfc_prob)
print(auc(fpr, tpr))
# Out:
# 0.533456220473
# 0.533456220473
